# %% [markdown]
# ### Custom exception (Raise and Throw and exception)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("Enter the dob (year of birth): "))
age = 2026 - year

try:
    if age <= 30 and age >= 20:
        print("The age is valid so you can apply for the exam")
    else:
        raise dobException
except dobException:
    print("Sorry your age should be greater then 20 and less then 30")
# Out:
# Sorry your age should be greater then 20 and less then 30
